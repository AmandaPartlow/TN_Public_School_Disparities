# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %matplotlib inline

# %%
elem = gpd.read_file('../data/final_data/elementary_gdf.geojson')
middle = gpd.read_file('../data/final_data/middle_gdf.geojson')
high = gpd.read_file('../data/final_data/high_gdf.geojson')

# %%
elem.head()
# Out:
#   census_block_group  income_per_cap  total_block_pop  white  black  \
# 0       470370101031         35527.0              937    918      0
# 1       470370101032         30055.0             1690   1504    144
# 2       470370101041         33533.0             1442   1134    209
# 3       470370101042         28406.0             1379   1370      9
# 4       470370101051         27498.0              663    351    279
#
#    nat_american_nat_alaskan  asian  pac_islander_nat_hawaiian  other  \
# 0                         0      0                          0     10
# 1                         5      0                          0      0
# 2                        11      0                         23     11
# 3                         0      0                          0      0
# 4                        12      0                          0     14
#
#    more_than_one_race  ...  hh_income_150,000-199,999  hh_income_200,000+  \
# ...

# %%
middle.head()
# Out:
#   census_block_group  income_per_cap  total_block_pop  white  black  \
# 0       470370101031         35527.0              937    918      0
# 1       470370101032         30055.0             1690   1504    144
# 2       470370101041         33533.0             1442   1134    209
# 3       470370101042         28406.0             1379   1370      9
# 4       470370101051         27498.0              663    351    279
#
#    nat_american_nat_alaskan  asian  pac_islander_nat_hawaiian  other  \
# 0                         0      0                          0     10
# 1                         5      0                          0      0
# 2                        11      0                         23     11
# 3                         0      0                          0      0
# 4                        12      0                          0     14
#
#    more_than_one_race  ...  hh_income_150,000-199,999  hh_income_200,000+  \
# ...

# %%
high.head()
# Out:
#   census_block_group  income_per_cap  total_block_pop  white  black  \
# 0       470370101031         35527.0              937    918      0
# 1       470370101032         30055.0             1690   1504    144
# 2       470370101041         33533.0             1442   1134    209
# 3       470370101042         28406.0             1379   1370      9
# 4       470370101051         27498.0              663    351    279
#
#    nat_american_nat_alaskan  asian  pac_islander_nat_hawaiian  other  \
# 0                         0      0                          0     10
# 1                         5      0                          0      0
# 2                        11      0                         23     11
# 3                         0      0                          0      0
# 4                        12      0                          0     14
#
#    more_than_one_race  ...  hh_income_150,000-199,999  hh_income_200,000+  \
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = elem.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
for col in elem.columns: 
    print(col)
# Out:
# census_block_group
# income_per_cap
# total_block_pop
# white
# black
# nat_american_nat_alaskan
# asian
# pac_islander_nat_hawaiian
# other
# more_than_one_race
# hispanic
# %white
# %black
# %hisp
# %non-white
# hh_income_<10,000
# hh_income_10,000-14,999
# hh_income_15,000-19,999
# hh_income_20,000-24,999
# hh_income_25,000-29,999
# hh_income_30,000-34,999
# hh_income_35,000-39,999
# hh_income_40,000-44,999
# hh_income_45,000-49,999
# hh_income_50,000-59,999
# hh_income_60,000-74,999
# hh_income_75,000-99,999
# hh_income_100,000-124,999
# hh_income_125,000-149,999
# hh_income_150,000-199,999
# hh_income_200,000+
# state
# county
# index_right
# school
# achievement_score
# growth_score
# chronically_out_of_school_score
# geometry

# %%
elem_lim = elem[['income_per_cap', '%non-white', '%white', 'achievement_score']]

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = elem_lim.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
middle_lim = middle[['income_per_cap', '%non-white', '%white', 'achievement_score']]

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = middle_lim.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
high_lim = high[['income_per_cap', '%non-white', '%white', 'achievement_score']]

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = high_lim.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
