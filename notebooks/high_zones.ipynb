# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
high_zones_first = gpd.read_file('../data/mnps/MNPS_HSZone_2021.shp')

# %%
high_zones_first.head(15)
# Out:
#        Shape_Leng    Shape_Area  CODE  \
# 0   229868.336792  1.167063e+09   110
# 1   167154.722925  8.250695e+08   182
# 2   153163.808014  5.913740e+08   615
# 3   104374.857986  4.735933e+08   325
# 4   177108.141081  1.259720e+09   435
# 5   301827.568394  1.951841e+09   532
# 6    99671.764789  3.132218e+08   705
# 7   120137.419681  3.938339e+08   550
# 8   286726.288008  1.415426e+09   452
# 9   402729.549271  3.477715e+09   787
# 10  299731.785485  2.413807e+09   440
# 11  113118.641510  3.584773e+08   632
#
#                                            SCHOOL_NAM     CLUS_NAME  \
# 0                                 Antioch High School       ANTIOCH
# 1                              Cane Ridge High School    CANE RIDGE
# 2                            John Overton High School       OVERTON
# 3                               Glencliff High School     GLENCLIFF
# 4                               Hillsboro High School     HILLSBORO
# ...

# %%
high_zones_first.shape
# Out:
# (12, 6)

# %%
print(high_zones_first.crs)
high_zones_first.head()
# Out:
# epsg:2274
#       Shape_Leng    Shape_Area  CODE                SCHOOL_NAM   CLUS_NAME  \
# 0  229868.336792  1.167063e+09   110       Antioch High School     ANTIOCH
# 1  167154.722925  8.250695e+08   182    Cane Ridge High School  CANE RIDGE
# 2  153163.808014  5.913740e+08   615  John Overton High School     OVERTON
# 3  104374.857986  4.735933e+08   325     Glencliff High School   GLENCLIFF
# 4  177108.141081  1.259720e+09   435     Hillsboro High School   HILLSBORO
#
#                                             geometry
# 0  POLYGON ((1813162.200 657380.000, 1813035.400 ...
# 1  POLYGON ((1758041.000 619591.200, 1757728.800 ...
# 2  POLYGON ((1757728.800 619668.950, 1758041.000 ...
# 3  POLYGON ((1754450.700 656866.508, 1754457.615 ...
# 4  POLYGON ((1734657.535 665641.719, 1734740.356 ...

# %%
high_zones_first = high_zones_first.to_crs('EPSG:2274')

# %%
print(high_zones_first.crs)
high_zones_first.head()
# Out:
# epsg:2274
#       Shape_Leng    Shape_Area  CODE                SCHOOL_NAM   CLUS_NAME  \
# 0  229868.336792  1.167063e+09   110       Antioch High School     ANTIOCH
# 1  167154.722925  8.250695e+08   182    Cane Ridge High School  CANE RIDGE
# 2  153163.808014  5.913740e+08   615  John Overton High School     OVERTON
# 3  104374.857986  4.735933e+08   325     Glencliff High School   GLENCLIFF
# 4  177108.141081  1.259720e+09   435     Hillsboro High School   HILLSBORO
#
#                                             geometry
# 0  POLYGON ((1813162.200 657380.000, 1813035.400 ...
# 1  POLYGON ((1758041.000 619591.200, 1757728.800 ...
# 2  POLYGON ((1757728.800 619668.950, 1758041.000 ...
# 3  POLYGON ((1754450.700 656866.508, 1754457.615 ...
# 4  POLYGON ((1734657.535 665641.719, 1734740.356 ...

# %%
high_zones_first = high_zones_first.to_crs('EPSG:4326')
print(high_zones_first.crs)
high_zones_first.head()
# Out:
# EPSG:4326
#       Shape_Leng    Shape_Area  CODE                SCHOOL_NAM   CLUS_NAME  \
# 0  229868.336792  1.167063e+09   110       Antioch High School     ANTIOCH
# 1  167154.722925  8.250695e+08   182    Cane Ridge High School  CANE RIDGE
# 2  153163.808014  5.913740e+08   615  John Overton High School     OVERTON
# 3  104374.857986  4.735933e+08   325     Glencliff High School   GLENCLIFF
# 4  177108.141081  1.259720e+09   435     Hillsboro High School   HILLSBORO
#
#                                             geometry
# 0  POLYGON ((-86.52606 36.13814, -86.52649 36.137...
# 1  POLYGON ((-86.71180 36.03337, -86.71286 36.033...
# 2  POLYGON ((-86.71286 36.03358, -86.71180 36.033...
# 3  POLYGON ((-86.72488 36.13569, -86.72485 36.135...
# 4  POLYGON ((-86.79214 36.15938, -86.79186 36.159...

# %%
f, ax = plt.subplots(1, figsize=(15, 15))
high_zones_first.plot(column = 'SCHOOL_NAM', edgecolor = 'black', ax = ax)
plt.show()

# %%
scores = pd.read_csv('../data/davidson_scores.csv').drop('Unnamed: 0', axis = 1)

# %%
scores.head()
# Out:
#                    SCHOOL POOL  ACHIEVEMENT_SCORE  GROWTH_SCORE  \
# 0  Crieve Hall Elementary   K8                4.0           3.0
# 1    Dan Mills Elementary   K8                4.0           4.0
# 2        Eakin Elementary   K8                4.0           4.0
# 3     Glendale Elementary   K8                4.0           4.0
# 4     Granbery Elementary   K8                4.0           4.0
#
#    CHRONICALLY_OUT_OF_SCHOOL_SCORE
# 0                              4.0
# 1                              3.0
# 2                              4.0
# 3                              4.0
# 4                              3.0

# %%
high_scores = scores[(scores['SCHOOL'].str.contains('High')) | 
                       (scores['SCHOOL'].str.contains('Stratford STEM Magnet School'))]
                      
high_scores.shape
# Out:
# (20, 5)

# %%
# for i in high_scores['SCHOOL'].values:
#     print(i)

# %%
high_scores_schools = []

for index, rows in high_scores.iterrows():
    
    high_scores_schools_list = (rows['SCHOOL'])
    
    high_scores_schools.append(high_scores_schools_list)
    
print(high_scores_schools)
# Out:
# ['Hume - Fogg High', 'Middle College High', 'Nashville Big Picture High School', 'Hillsboro High', 'John Overton High', 'KIPP Nashville Collegiate High School', 'Antioch High School', 'Cane Ridge High School', 'East Nashville Magnet High School', 'Glencliff High School', 'Hillwood High', 'Hunters Lane High', 'Maplewood High', 'McGavock High', 'Pearl-Cohn High', 'Stratford STEM Magnet School', 'Knowledge Academies High School', 'STEM Prep High School', 'Whites Creek High', 'RePublic High School']

# %%
high_zones_schools = []

for index, rows in high_zones_first.iterrows():
    
    high_zones_schools_list = (rows['SCHOOL_NAM'])
    
    high_zones_schools.append(high_zones_schools_list)
    
print(high_zones_schools)
# Out:
# ['Antioch High School', 'Cane Ridge High School', 'John Overton High School', 'Glencliff High School', 'Hillsboro High School', 'McGavock High School', 'Stratford STEM Magnet School - Upper/Lower Campus', 'Maplewood High School', 'Hunters Lane High School', 'Whites Creek High School', 'Hillwood High School', 'Pearl-Cohn High School']

# %%
high_scores_schools = sorted(high_scores_schools)
print(high_scores_schools)
# Out:
# ['Antioch High School', 'Cane Ridge High School', 'East Nashville Magnet High School', 'Glencliff High School', 'Hillsboro High', 'Hillwood High', 'Hume - Fogg High', 'Hunters Lane High', 'John Overton High', 'KIPP Nashville Collegiate High School', 'Knowledge Academies High School', 'Maplewood High', 'McGavock High', 'Middle College High', 'Nashville Big Picture High School', 'Pearl-Cohn High', 'RePublic High School', 'STEM Prep High School', 'Stratford STEM Magnet School', 'Whites Creek High']

# %%
high_zones_schools = sorted(high_zones_schools)
print(high_zones_schools)
# Out:
# ['Antioch High School', 'Cane Ridge High School', 'Glencliff High School', 'Hillsboro High School', 'Hillwood High School', 'Hunters Lane High School', 'John Overton High School', 'Maplewood High School', 'McGavock High School', 'Pearl-Cohn High School', 'Stratford STEM Magnet School - Upper/Lower Campus', 'Whites Creek High School']

# %% [markdown]
# zones:
#
# scores: 'East Nashville Magnet High School', 'Hume - Fogg High', 'KIPP Nashville Collegiate High School', 'Knowledge Academies High School', 'Middle College High', 'Nashville Big Picture High School', 'RePublic High School', 'STEM Prep High School',
#
# both: 'Antioch High School', 'Cane Ridge High School', 'Glencliff High School', 'Hillsboro High', 'Hillwood High', 'Hunters Lane High', 'John Overton High', 'Maplewood High', 'McGavock High', 'Pearl-Cohn High', 'Stratford STEM Magnet School', 'Whites Creek High'

# %%
high_scores = scores[(scores['SCHOOL'].str.contains('Antioch High School')) | 
                       (scores['SCHOOL'].str.contains('Cane Ridge High School')) |
                       (scores['SCHOOL'].str.contains('Glencliff High School')) |
                       (scores['SCHOOL'].str.contains('Hillsboro High')) |
                       (scores['SCHOOL'].str.contains('Hillwood High')) |
                       (scores['SCHOOL'].str.contains('Hunters Lane High')) |
                       (scores['SCHOOL'].str.contains('John Overton High')) |
                       (scores['SCHOOL'].str.contains('Maplewood High')) |
                       (scores['SCHOOL'].str.contains('McGavock High')) |
                       (scores['SCHOOL'].str.contains('Pearl-Cohn High')) |
                       (scores['SCHOOL'].str.contains('Stratford STEM Magnet School')) |
                       (scores['SCHOOL'].str.contains('Whites Creek High')) ]
                      
high_scores.head(13)
# Out:
#                            SCHOOL POOL  ACHIEVEMENT_SCORE  GROWTH_SCORE  \
# 67                 Hillsboro High   HS                2.0           0.0
# 71              John Overton High   HS                2.0           0.0
# 91            Antioch High School   HS                1.0           0.0
# 94         Cane Ridge High School   HS                1.0           0.0
# 106         Glencliff High School   HS                1.0           0.0
# 114                 Hillwood High   HS                1.0           0.0
# 116             Hunters Lane High   HS                1.0           0.0
# 122                Maplewood High   HS                1.0           0.0
# 124                 McGavock High   HS                1.0           0.0
# 129               Pearl-Cohn High   HS                1.0           0.0
# 130  Stratford STEM Magnet School   HS                1.0           0.0
# 145             Whites Creek High   HS                0.0           0.0
#
# ...

# %%
high_zones_first.head(13)
# Out:
#        Shape_Leng    Shape_Area  CODE  \
# 0   229868.336792  1.167063e+09   110
# 1   167154.722925  8.250695e+08   182
# 2   153163.808014  5.913740e+08   615
# 3   104374.857986  4.735933e+08   325
# 4   177108.141081  1.259720e+09   435
# 5   301827.568394  1.951841e+09   532
# 6    99671.764789  3.132218e+08   705
# 7   120137.419681  3.938339e+08   550
# 8   286726.288008  1.415426e+09   452
# 9   402729.549271  3.477715e+09   787
# 10  299731.785485  2.413807e+09   440
# 11  113118.641510  3.584773e+08   632
#
#                                            SCHOOL_NAM     CLUS_NAME  \
# 0                                 Antioch High School       ANTIOCH
# 1                              Cane Ridge High School    CANE RIDGE
# 2                            John Overton High School       OVERTON
# 3                               Glencliff High School     GLENCLIFF
# 4                               Hillsboro High School     HILLSBORO
# ...

# %%
high_zones_order = high_zones_first.sort_values(['SCHOOL_NAM'])
high_zones_order.head(12)
# Out:
#        Shape_Leng    Shape_Area  CODE  \
# 0   229868.336792  1.167063e+09   110
# 1   167154.722925  8.250695e+08   182
# 3   104374.857986  4.735933e+08   325
# 4   177108.141081  1.259720e+09   435
# 10  299731.785485  2.413807e+09   440
# 8   286726.288008  1.415426e+09   452
# 2   153163.808014  5.913740e+08   615
# 7   120137.419681  3.938339e+08   550
# 5   301827.568394  1.951841e+09   532
# 11  113118.641510  3.584773e+08   632
# 6    99671.764789  3.132218e+08   705
# 9   402729.549271  3.477715e+09   787
#
#                                            SCHOOL_NAM     CLUS_NAME  \
# 0                                 Antioch High School       ANTIOCH
# 1                              Cane Ridge High School    CANE RIDGE
# 3                               Glencliff High School     GLENCLIFF
# 4                               Hillsboro High School     HILLSBORO
# 10                               Hillwood High School      HILLWOOD
# ...

# %%
high_scores_order = high_scores.sort_values(['SCHOOL'])
high_scores_order.head(12)
# Out:
#                            SCHOOL POOL  ACHIEVEMENT_SCORE  GROWTH_SCORE  \
# 91            Antioch High School   HS                1.0           0.0
# 94         Cane Ridge High School   HS                1.0           0.0
# 106         Glencliff High School   HS                1.0           0.0
# 67                 Hillsboro High   HS                2.0           0.0
# 114                 Hillwood High   HS                1.0           0.0
# 116             Hunters Lane High   HS                1.0           0.0
# 71              John Overton High   HS                2.0           0.0
# 122                Maplewood High   HS                1.0           0.0
# 124                 McGavock High   HS                1.0           0.0
# 129               Pearl-Cohn High   HS                1.0           0.0
# 130  Stratford STEM Magnet School   HS                1.0           0.0
# 145             Whites Creek High   HS                0.0           0.0
#
# ...

# %%
high_zones_order = high_zones_order.reset_index()
high_zones_order.head(12)
# Out:
#     index     Shape_Leng    Shape_Area  CODE  \
# 0       0  229868.336792  1.167063e+09   110
# 1       1  167154.722925  8.250695e+08   182
# 2       3  104374.857986  4.735933e+08   325
# 3       4  177108.141081  1.259720e+09   435
# 4      10  299731.785485  2.413807e+09   440
# 5       8  286726.288008  1.415426e+09   452
# 6       2  153163.808014  5.913740e+08   615
# 7       7  120137.419681  3.938339e+08   550
# 8       5  301827.568394  1.951841e+09   532
# 9      11  113118.641510  3.584773e+08   632
# 10      6   99671.764789  3.132218e+08   705
# 11      9  402729.549271  3.477715e+09   787
#
#                                            SCHOOL_NAM     CLUS_NAME  \
# 0                                 Antioch High School       ANTIOCH
# 1                              Cane Ridge High School    CANE RIDGE
# 2                               Glencliff High School     GLENCLIFF
# 3                               Hillsboro High School     HILLSBORO
# ...

# %%
high_scores_order = high_scores_order.reset_index()
high_scores_order.head(12)
# Out:
#     index                        SCHOOL POOL  ACHIEVEMENT_SCORE  GROWTH_SCORE  \
# 0      91           Antioch High School   HS                1.0           0.0
# 1      94        Cane Ridge High School   HS                1.0           0.0
# 2     106         Glencliff High School   HS                1.0           0.0
# 3      67                Hillsboro High   HS                2.0           0.0
# 4     114                 Hillwood High   HS                1.0           0.0
# 5     116             Hunters Lane High   HS                1.0           0.0
# 6      71             John Overton High   HS                2.0           0.0
# 7     122                Maplewood High   HS                1.0           0.0
# 8     124                 McGavock High   HS                1.0           0.0
# 9     129               Pearl-Cohn High   HS                1.0           0.0
# 10    130  Stratford STEM Magnet School   HS                1.0           0.0
# ...

# %%
high_zones_scores = high_zones_order.merge(high_scores_order, how='outer', left_index=True, right_index=True)

# %%
high_zones_scores.head(12)
# Out:
#     index_x     Shape_Leng    Shape_Area  CODE  \
# 0         0  229868.336792  1.167063e+09   110
# 1         1  167154.722925  8.250695e+08   182
# 2         3  104374.857986  4.735933e+08   325
# 3         4  177108.141081  1.259720e+09   435
# 4        10  299731.785485  2.413807e+09   440
# 5         8  286726.288008  1.415426e+09   452
# 6         2  153163.808014  5.913740e+08   615
# 7         7  120137.419681  3.938339e+08   550
# 8         5  301827.568394  1.951841e+09   532
# 9        11  113118.641510  3.584773e+08   632
# 10        6   99671.764789  3.132218e+08   705
# 11        9  402729.549271  3.477715e+09   787
#
#                                            SCHOOL_NAM     CLUS_NAME  \
# 0                                 Antioch High School       ANTIOCH
# 1                              Cane Ridge High School    CANE RIDGE
# 2                               Glencliff High School     GLENCLIFF
# 3                               Hillsboro High School     HILLSBORO
# ...

# %%
high_zones_scores.shape
# Out:
# (12, 13)

# %%
high_zones_scores = high_zones_scores[['SCHOOL_NAM',
                                           'ACHIEVEMENT_SCORE',
                                           'GROWTH_SCORE',
                                           'CHRONICALLY_OUT_OF_SCHOOL_SCORE',
                                           'geometry']]
high_zones_scores.head()
# Out:
#                SCHOOL_NAM  ACHIEVEMENT_SCORE  GROWTH_SCORE  \
# 0     Antioch High School                1.0           0.0
# 1  Cane Ridge High School                1.0           0.0
# 2   Glencliff High School                1.0           0.0
# 3   Hillsboro High School                2.0           0.0
# 4    Hillwood High School                1.0           0.0
#
#    CHRONICALLY_OUT_OF_SCHOOL_SCORE  \
# 0                              4.0
# 1                              3.0
# 2                              3.0
# 3                              4.0
# 4                              3.0
#
#                                             geometry
# 0  POLYGON ((-86.52606 36.13814, -86.52649 36.137...
# 1  POLYGON ((-86.71180 36.03337, -86.71286 36.033...
# 2  POLYGON ((-86.72488 36.13569, -86.72485 36.135...
# 3  POLYGON ((-86.79214 36.15938, -86.79186 36.159...
# 4  POLYGON ((-86.96663 36.20837, -86.96631 36.208...

# %%
high_zones_scores = high_zones_scores.rename(columns={'SCHOOL_NAM': 'school',
                                                          'ACHIEVEMENT_SCORE': 'achievement_score',
                                                          'GROWTH_SCORE': 'growth_score',
                                                          'CHRONICALLY_OUT_OF_SCHOOL_SCORE': 'chronically_out_of_school_score'})

high_zones_scores.head()
# Out:
#                    school  achievement_score  growth_score  \
# 0     Antioch High School                1.0           0.0
# 1  Cane Ridge High School                1.0           0.0
# 2   Glencliff High School                1.0           0.0
# 3   Hillsboro High School                2.0           0.0
# 4    Hillwood High School                1.0           0.0
#
#    chronically_out_of_school_score  \
# 0                              4.0
# 1                              3.0
# 2                              3.0
# 3                              4.0
# 4                              3.0
#
#                                             geometry
# 0  POLYGON ((-86.52606 36.13814, -86.52649 36.137...
# 1  POLYGON ((-86.71180 36.03337, -86.71286 36.033...
# 2  POLYGON ((-86.72488 36.13569, -86.72485 36.135...
# 3  POLYGON ((-86.79214 36.15938, -86.79186 36.159...
# 4  POLYGON ((-86.96663 36.20837, -86.96631 36.208...

# %%
type(high_zones_scores)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
f, ax = plt.subplots(1, figsize=(15, 15))
high_zones_scores.plot(column = 'school', edgecolor = 'black', ax = ax, legend = True)
plt.show()

# %%
high_zones_scores.shape
# Out:
# (12, 5)

# %%
high_zones_scores.head(28)
# Out:
#                                                school  achievement_score  \
# 0                                 Antioch High School                1.0
# 1                              Cane Ridge High School                1.0
# 2                               Glencliff High School                1.0
# 3                               Hillsboro High School                2.0
# 4                                Hillwood High School                1.0
# 5                            Hunters Lane High School                1.0
# 6                            John Overton High School                2.0
# 7                               Maplewood High School                1.0
# 8                                McGavock High School                1.0
# 9                              Pearl-Cohn High School                1.0
# 10  Stratford STEM Magnet School - Upper/Lower Campus                1.0
# 11                           Whites Creek High School                0.0
#
# ...

# %%
high_zones_scores_gdf = gpd.GeoDataFrame(high_zones_scores, geometry='geometry')
high_zones_scores_gdf.to_file('../data/final_data/high_zones_scores_gdf.geojson', driver = 'GeoJSON')
