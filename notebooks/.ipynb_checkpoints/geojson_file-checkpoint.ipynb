# %%
import pandas as pd
import geopandas as gpd

# %%
geometry = gpd.read_file('../data/safegraph_open_census_data/geometry/cbg.geojson')

# %%
print(geometry.crs)
# Out:
# epsg:4326

# %%
geometry.crs = "EPSG:4326"
print(geometry.crs)
# Out:
# EPSG:4326

# %%
geometry.head()
# Out:
#   StateFIPS CountyFIPS TractCode BlockGroup CensusBlockGroup State  \
# 0        01        081    041600          1     010810416001    AL
# 1        01        081    041600          2     010810416002    AL
# 2        01        081    041700          4     010810417004    AL
# 3        01        073    011107          4     010730111074    AL
# 4        01        073    011108          4     010730111084    AL
#
#              County ClassCode  \
# 0        Lee County        H1
# 1        Lee County        H1
# 2        Lee County        H1
# 3  Jefferson County        H1
# 4  Jefferson County        H1
#
#                                             geometry
# 0  MULTIPOLYGON (((-85.37282 32.63424, -85.37275 ...
# 1  MULTIPOLYGON (((-85.38346 32.64838, -85.38301 ...
# 2  MULTIPOLYGON (((-85.37139 32.60139, -85.37138 ...
# 3  MULTIPOLYGON (((-86.64797 33.59205, -86.64771 ...
# 4  MULTIPOLYGON (((-86.65206 33.59869, -86.65204 ...

# %%
per_cap = pd.read_csv('../data/census_data_income_per_cap_2.csv').drop('Unnamed: 0', axis = 1)

# %%
per_cap.tail()
# Out:
#         census_block_group  income_per_cap
# 220328        721537506011          5234.0
# 220329        721537506012          9036.0
# 220330        721537506013         15248.0
# 220331        721537506021          4997.0
# 220332        721537506022          5330.0

# %%
per_cap.shape
# Out:
# (220333, 2)

# %%
geometry.dtypes
# Out:
# StateFIPS             object
# CountyFIPS            object
# TractCode             object
# BlockGroup            object
# CensusBlockGroup      object
# State                 object
# County                object
# ClassCode             object
# geometry            geometry
# dtype: object

# %%
per_cap.dtypes
# Out:
# census_block_group      int64
# income_per_cap        float64
# dtype: object

# %%
geometry.CensusBlockGroup = geometry.CensusBlockGroup.astype(str)
geometry.shape
# Out:
# (220333, 9)

# %%
geometry.head()
# Out:
#   StateFIPS CountyFIPS TractCode BlockGroup CensusBlockGroup State  \
# 0        01        081    041600          1     010810416001    AL
# 1        01        081    041600          2     010810416002    AL
# 2        01        081    041700          4     010810417004    AL
# 3        01        073    011107          4     010730111074    AL
# 4        01        073    011108          4     010730111084    AL
#
#              County ClassCode  \
# 0        Lee County        H1
# 1        Lee County        H1
# 2        Lee County        H1
# 3  Jefferson County        H1
# 4  Jefferson County        H1
#
#                                             geometry
# 0  MULTIPOLYGON (((-85.37282 32.63424, -85.37275 ...
# 1  MULTIPOLYGON (((-85.38346 32.64838, -85.38301 ...
# 2  MULTIPOLYGON (((-85.37139 32.60139, -85.37138 ...
# 3  MULTIPOLYGON (((-86.64797 33.59205, -86.64771 ...
# 4  MULTIPOLYGON (((-86.65206 33.59869, -86.65204 ...

# %%
per_cap.census_block_group = per_cap.census_block_group.astype(str)
per_cap.head()
# Out:
#   census_block_group  income_per_cap
# 0        10010201001         20365.0
# 1        10010201002         33336.0
# 2        10010202001         17047.0
# 3        10010202002         21400.0
# 4        10010203001         23106.0

# %%
geo_per_cap = pd.merge(per_cap, geometry, left_on='census_block_group', right_on='CensusBlockGroup')
geo_per_cap.head()
# Out:
#   census_block_group  income_per_cap StateFIPS CountyFIPS TractCode  \
# 0       100010401001         24302.0        10        001    040100
# 1       100010401002         27198.0        10        001    040100
# 2       100010401003         26313.0        10        001    040100
# 3       100010402011         24056.0        10        001    040201
# 4       100010402012         27699.0        10        001    040201
#
#   BlockGroup CensusBlockGroup State       County ClassCode  \
# 0          1     100010401001    DE  Kent County        H1
# 1          2     100010401002    DE  Kent County        H1
# 2          3     100010401003    DE  Kent County        H1
# 3          1     100010402011    DE  Kent County        H1
# 4          2     100010402012    DE  Kent County        H1
#
#                                             geometry
# 0  MULTIPOLYGON (((-75.76002 39.29682, -75.75626 ...
# 1  MULTIPOLYGON (((-75.75697 39.25807, -75.75652 ...
# ...

# %%
geo_per_cap.shape
# Out:
# (180707, 11)

# %%
TN = geo_per_cap.loc[geo_per_cap['State'] == 'TN']
TN.shape
# Out:
# (4125, 11)

# %%
Davidson_per_cap = TN.loc[TN['County'] == 'Davidson County']
Davidson_per_cap.shape
# Out:
# (473, 11)

# %%
TN_test = geometry.loc[geometry['State'] == 'TN']
TN_test.shape
# Out:
# (4125, 9)

# %%
Davidson_test = TN_test.loc[TN_test['County'] == 'Davidson County']
Davidson_test.shape
# Out:
# (473, 9)

# %%
Davidson_per_cap.head()
# Out:
#        census_block_group  income_per_cap StateFIPS CountyFIPS TractCode  \
# 139858       470370101031         35527.0        47        037    010103
# 139859       470370101032         30055.0        47        037    010103
# 139860       470370101041         33533.0        47        037    010104
# 139861       470370101042         28406.0        47        037    010104
# 139862       470370101051         27498.0        47        037    010105
#
#        BlockGroup CensusBlockGroup State           County ClassCode  \
# 139858          1     470370101031    TN  Davidson County        H6
# 139859          2     470370101032    TN  Davidson County        H6
# 139860          1     470370101041    TN  Davidson County        H6
# 139861          2     470370101042    TN  Davidson County        H6
# 139862          1     470370101051    TN  Davidson County        H6
#
#                                                  geometry
# 139858  MULTIPOLYGON (((-86.91752 36.33976, -86.91747 ...
# ...

# %%
Davidson_per_cap = Davidson_per_cap[['census_block_group',
                                     'income_per_cap',
                                     'State',
                                     'County',
                                     'geometry']]

Davidson_per_cap.head()
# Out:
#        census_block_group  income_per_cap State           County  \
# 139858       470370101031         35527.0    TN  Davidson County
# 139859       470370101032         30055.0    TN  Davidson County
# 139860       470370101041         33533.0    TN  Davidson County
# 139861       470370101042         28406.0    TN  Davidson County
# 139862       470370101051         27498.0    TN  Davidson County
#
#                                                  geometry
# 139858  MULTIPOLYGON (((-86.91752 36.33976, -86.91747 ...
# 139859  MULTIPOLYGON (((-86.88288 36.35786, -86.88219 ...
# 139860  MULTIPOLYGON (((-86.89607 36.28446, -86.89606 ...
# 139861  MULTIPOLYGON (((-86.97440 36.24991, -86.97244 ...
# 139862  MULTIPOLYGON (((-86.87347 36.27968, -86.87345 ...

# %%
Davidson_per_cap = Davidson_per_cap.rename(columns={'State': 'state',
                                                    'County': 'county'})
Davidson_per_cap.head(20)
# Out:
#        census_block_group  income_per_cap state           county  \
# 139858       470370101031         35527.0    TN  Davidson County
# 139859       470370101032         30055.0    TN  Davidson County
# 139860       470370101041         33533.0    TN  Davidson County
# 139861       470370101042         28406.0    TN  Davidson County
# 139862       470370101051         27498.0    TN  Davidson County
# 139863       470370101052         29534.0    TN  Davidson County
# 139864       470370101053         24254.0    TN  Davidson County
# 139865       470370101054         20644.0    TN  Davidson County
# 139866       470370101061         21403.0    TN  Davidson County
# 139867       470370101062         16564.0    TN  Davidson County
# 139868       470370102011         24800.0    TN  Davidson County
# 139869       470370102012         36108.0    TN  Davidson County
# 139870       470370102013         26655.0    TN  Davidson County
# ...

# %%
Davidson_per_cap.shape
# Out:
# (473, 5)

# %%
Davidson_per_cap_gdf = gpd.GeoDataFrame(Davidson_per_cap, geometry='geometry')

# %%
Davidson_per_cap_gdf.to_file('../data/final_data/davidson_per_cap.geojson', driver = 'GeoJSON')

# %%
race = pd.read_csv('../data/census_data_race_2.csv').drop('Unnamed: 0', axis = 1)
race.head()
# Out:
#    census_block_group  total_block_pop  white  black  \
# 0         10010201001              745    585    160
# 1         10010201002             1265   1083    104
# 2         10010202001              960    361    568
# 3         10010202002             1236    615    571
# 4         10010203001             2364   1481    515
#
#    native_american_/_alaskan_native  asian  \
# 0                                 0      0
# 1                                 0      9
# 2                                 0      0
# 3                                 0     24
# 4                                22     27
#
#    pacific_islander_/_native_hawaiian  other  more_than_one_race  hispanic  \
# 0                                   0      0                   0        16
# 1                                   0      0                  69        37
# 2                                  13      0                  18        13
# 3                                   0     10                  16        15
# ...

# %%
race.census_block_group = race.census_block_group.astype(str)
race.head()
# Out:
#   census_block_group  total_block_pop  white  black  \
# 0        10010201001              745    585    160
# 1        10010201002             1265   1083    104
# 2        10010202001              960    361    568
# 3        10010202002             1236    615    571
# 4        10010203001             2364   1481    515
#
#    native_american_/_alaskan_native  asian  \
# 0                                 0      0
# 1                                 0      9
# 2                                 0      0
# 3                                 0     24
# 4                                22     27
#
#    pacific_islander_/_native_hawaiian  other  more_than_one_race  hispanic  \
# 0                                   0      0                   0        16
# 1                                   0      0                  69        37
# 2                                  13      0                  18        13
# 3                                   0     10                  16        15
# ...

# %%
race = race[['census_block_group',
             'total_block_pop',
             'white',
             'black',
             'native_american_/_alaskan_native',
             'asian',
             'pacific_islander_/_native_hawaiian',
             'other',
             'more_than_one_race',
             'hispanic',
             'hispanic - white',
             '%white',
             '%black',
             '%hisp',
             '%non-white']]

race.head()
# Out:
#   census_block_group  total_block_pop  white  black  \
# 0        10010201001              745    585    160
# 1        10010201002             1265   1083    104
# 2        10010202001              960    361    568
# 3        10010202002             1236    615    571
# 4        10010203001             2364   1481    515
#
#    native_american_/_alaskan_native  asian  \
# 0                                 0      0
# 1                                 0      9
# 2                                 0      0
# 3                                 0     24
# 4                                22     27
#
#    pacific_islander_/_native_hawaiian  other  more_than_one_race  hispanic  \
# 0                                   0      0                   0        16
# 1                                   0      0                  69        37
# 2                                  13      0                  18        13
# 3                                   0     10                  16        15
# ...

# %%
list(race.columns.values)
# Out:
# ['census_block_group',
#  'total_block_pop',
#  'white',
#  'black',
#  'native_american_/_alaskan_native',
#  'asian',
#  'pacific_islander_/_native_hawaiian',
#  'other',
#  'more_than_one_race',
#  'hispanic',
#  'hispanic - white',
#  '%white',
#  '%black',
#  '%hisp',
#  '%non-white']

# %%
race_geo = pd.merge(race, geometry, left_on='census_block_group', right_on='CensusBlockGroup')
race_geo.head()
# Out:
#   census_block_group  total_block_pop  white  black  \
# 0       100010401001             3203   2901    221
# 1       100010401002             1772   1553    133
# 2       100010401003             1523   1314    135
# 3       100010402011             2572   1943    443
# 4       100010402012             2571   1699    632
#
#    native_american_/_alaskan_native  asian  \
# 0                                 0      0
# 1                                10      2
# 2                                19     34
# 3                                13     30
# 4                                 0     61
#
#    pacific_islander_/_native_hawaiian  other  more_than_one_race  hispanic  \
# 0                                   0      0                  81       121
# 1                                   4     46                  24        79
# 2                                   0     10                  11        38
# 3                                   0     39                 104       189
# ...

# %%
race_geo.shape
# Out:
# (180707, 24)

# %%
list(race_geo.columns.values)
# Out:
# ['census_block_group',
#  'total_block_pop',
#  'white',
#  'black',
#  'native_american_/_alaskan_native',
#  'asian',
#  'pacific_islander_/_native_hawaiian',
#  'other',
#  'more_than_one_race',
#  'hispanic',
#  'hispanic - white',
#  '%white',
#  '%black',
#  '%hisp',
#  '%non-white',
#  'StateFIPS',
#  'CountyFIPS',
#  'TractCode',
#  'BlockGroup',
#  'CensusBlockGroup',
#  'State',
#  'County',
#  'ClassCode',
#  'geometry']

# %%
race_geo_TN = race_geo.loc[race_geo['State'] == 'TN']
race_geo_TN.shape
# Out:
# (4125, 24)

# %%
Davidson_race = race_geo_TN.loc[race_geo_TN['County'] == 'Davidson County']
Davidson_race.shape
# Out:
# (473, 24)

# %%
Davidson_race.head()
# Out:
#        census_block_group  total_block_pop  white  black  \
# 139858       470370101031              937    918      0
# 139859       470370101032             1690   1504    144
# 139860       470370101041             1442   1134    209
# 139861       470370101042             1379   1370      9
# 139862       470370101051              663    351    279
#
#         native_american_/_alaskan_native  asian  \
# 139858                                 0      0
# 139859                                 5      0
# 139860                                11      0
# 139861                                 0      0
# 139862                                12      0
#
#         pacific_islander_/_native_hawaiian  other  more_than_one_race  \
# 139858                                   0     10                   9
# 139859                                   0      0                  37
# 139860                                  23     11                  54
# ...

# %%
Davidson_race = Davidson_race[['census_block_group',
                               'total_block_pop',
                               'white',
                               'black',
                               'native_american_/_alaskan_native',
                               'asian',
                               'pacific_islander_/_native_hawaiian',
                               'other',
                               'more_than_one_race',
                               'hispanic',
                               'hispanic - white',
                               '%white',
                               '%black',
                               '%hisp',
                               '%non-white',
                               'State',
                               'County',
                               'geometry']]

Davidson_race.head()
# Out:
#        census_block_group  total_block_pop  white  black  \
# 139858       470370101031              937    918      0
# 139859       470370101032             1690   1504    144
# 139860       470370101041             1442   1134    209
# 139861       470370101042             1379   1370      9
# 139862       470370101051              663    351    279
#
#         native_american_/_alaskan_native  asian  \
# 139858                                 0      0
# 139859                                 5      0
# 139860                                11      0
# 139861                                 0      0
# 139862                                12      0
#
#         pacific_islander_/_native_hawaiian  other  more_than_one_race  \
# 139858                                   0     10                   9
# 139859                                   0      0                  37
# 139860                                  23     11                  54
# ...

# %%
Davidson_race = Davidson_race.rename(columns={'State': 'state',
                                                    'County': 'county'})
Davidson_race.head()
# Out:
#        census_block_group  total_block_pop  white  black  \
# 139858       470370101031              937    918      0
# 139859       470370101032             1690   1504    144
# 139860       470370101041             1442   1134    209
# 139861       470370101042             1379   1370      9
# 139862       470370101051              663    351    279
#
#         native_american_/_alaskan_native  asian  \
# 139858                                 0      0
# 139859                                 5      0
# 139860                                11      0
# 139861                                 0      0
# 139862                                12      0
#
#         pacific_islander_/_native_hawaiian  other  more_than_one_race  \
# 139858                                   0     10                   9
# 139859                                   0      0                  37
# 139860                                  23     11                  54
# ...

# %%
Davidson_race.shape
# Out:
# (473, 18)

# %%
Davidson_race_gdf = gpd.GeoDataFrame(Davidson_race, geometry='geometry')
Davidson_race_gdf.to_file('../data/final_data/davidson_race.geojson', driver = 'GeoJSON')

# %%
income = pd.read_csv('../data/census_data_income_2.csv').drop('Unnamed: 0', axis = 1)
income.head()
# Out:
#    census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 0         10010201001                 24                       33
# 1         10010201002                  8                       15
# 2         10010202001                 47                      108
# 3         10010202002                 32                       37
# 4         10010203001                 23                       34
#
#    hh_income_15,000-19,999  hh_income_20,000-24,999  hh_income_25,000-29,999  \
# 0                       23                       25                       39
# 1                       14                        5                       10
# 2                       37                        0                       23
# 3                       15                       18                       12
# 4                       16                       17                       47
#
#    hh_income_30,000-34,999  hh_income_35,000-39,999  hh_income_40,000-44,999  \
# ...

# %%
income.shape
# Out:
# (220333, 17)

# %%
income.census_block_group = income.census_block_group.astype(str)
income.head()
# Out:
#   census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 0        10010201001                 24                       33
# 1        10010201002                  8                       15
# 2        10010202001                 47                      108
# 3        10010202002                 32                       37
# 4        10010203001                 23                       34
#
#    hh_income_15,000-19,999  hh_income_20,000-24,999  hh_income_25,000-29,999  \
# 0                       23                       25                       39
# 1                       14                        5                       10
# 2                       37                        0                       23
# 3                       15                       18                       12
# 4                       16                       17                       47
#
#    hh_income_30,000-34,999  hh_income_35,000-39,999  hh_income_40,000-44,999  \
# ...

# %%
geo_income = pd.merge(income, geometry, left_on='census_block_group', right_on='CensusBlockGroup')
geo_income.head()
# Out:
#   census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 0       100010401001                104                       35
# 1       100010401002                  8                       43
# 2       100010401003                 22                       13
# 3       100010402011                  3                       47
# 4       100010402012                 44                       51
#
#    hh_income_15,000-19,999  hh_income_20,000-24,999  hh_income_25,000-29,999  \
# 0                       32                       19                       60
# 1                       16                       56                       26
# 2                       36                        0                        1
# 3                       28                       44                       53
# 4                       69                       34                       42
#
#    hh_income_30,000-34,999  hh_income_35,000-39,999  hh_income_40,000-44,999  \
# ...

# %%
geo_income.shape
# Out:
# (180707, 26)

# %%
TN_income = geo_income.loc[geo_income['State'] == 'TN']
TN_income.shape
# Out:
# (4125, 26)

# %%
Davidson_income = TN_income.loc[TN_income['County'] == 'Davidson County']
Davidson_income.shape
# Out:
# (473, 26)

# %%
Davidson_income.head()
# Out:
#        census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 139858       470370101031                 12                       14
# 139859       470370101032                 11                       34
# 139860       470370101041                 22                       25
# 139861       470370101042                 19                        7
# 139862       470370101051                  0                        0
#
#         hh_income_15,000-19,999  hh_income_20,000-24,999  \
# 139858                        5                       16
# 139859                        4                       18
# 139860                       56                       23
# 139861                       15                       57
# 139862                        7                       20
#
#         hh_income_25,000-29,999  hh_income_30,000-34,999  \
# 139858                       22                       14
# 139859                       41                        9
# ...

# %%
list(Davidson_income.columns.values)
# Out:
# ['census_block_group',
#  'hh_income_<10,000',
#  'hh_income_10,000-14,999',
#  'hh_income_15,000-19,999',
#  'hh_income_20,000-24,999',
#  'hh_income_25,000-29,999',
#  'hh_income_30,000-34,999',
#  'hh_income_35,000-39,999',
#  'hh_income_40,000-44,999',
#  'hh_income_45,000-49,999',
#  'hh_income_50,000-59,999',
#  'hh_income_60,000-74,999',
#  'hh_income_75,000-99,999',
#  'hh_income_100,000-124,999',
#  'hh_income_125,000-149,999',
#  'hh_income_150,000-199,999',
#  'hh_income_200,000+',
#  'StateFIPS',
#  'CountyFIPS',
#  'TractCode',
#  'BlockGroup',
#  'CensusBlockGroup',
#  'State',
#  'County',
#  'ClassCode',
#  'geometry']

# %%
Davidson_income = Davidson_income[['census_block_group',
                               'hh_income_<10,000',
                               'hh_income_10,000-14,999',
                               'hh_income_15,000-19,999',
                               'hh_income_20,000-24,999',
                               'hh_income_25,000-29,999',
                               'hh_income_30,000-34,999',
                                'hh_income_35,000-39,999',
                               'hh_income_40,000-44,999',
                               'hh_income_45,000-49,999',
                               'hh_income_50,000-59,999',
                               'hh_income_60,000-74,999',
                               'hh_income_75,000-99,999',
                               'hh_income_100,000-124,999',
                               'hh_income_125,000-149,999',
                               'hh_income_150,000-199,999',
                                'hh_income_200,000+',
                               'State',
                               'County',
                               'geometry']]

Davidson_income.head()
# Out:
#        census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 139858       470370101031                 12                       14
# 139859       470370101032                 11                       34
# 139860       470370101041                 22                       25
# 139861       470370101042                 19                        7
# 139862       470370101051                  0                        0
#
#         hh_income_15,000-19,999  hh_income_20,000-24,999  \
# 139858                        5                       16
# 139859                        4                       18
# 139860                       56                       23
# 139861                       15                       57
# 139862                        7                       20
#
#         hh_income_25,000-29,999  hh_income_30,000-34,999  \
# 139858                       22                       14
# 139859                       41                        9
# ...

# %%
Davidson_income = Davidson_income.rename(columns={'State': 'state',
                                                    'County': 'county'})
Davidson_income.head()
# Out:
#        census_block_group  hh_income_<10,000  hh_income_10,000-14,999  \
# 139858       470370101031                 12                       14
# 139859       470370101032                 11                       34
# 139860       470370101041                 22                       25
# 139861       470370101042                 19                        7
# 139862       470370101051                  0                        0
#
#         hh_income_15,000-19,999  hh_income_20,000-24,999  \
# 139858                        5                       16
# 139859                        4                       18
# 139860                       56                       23
# 139861                       15                       57
# 139862                        7                       20
#
#         hh_income_25,000-29,999  hh_income_30,000-34,999  \
# 139858                       22                       14
# 139859                       41                        9
# ...

# %%
# Davidson_income_gdf = gpd.GeoDataFrame(Davidson_income, geometry='geometry')
# Davidson_income_gdf.to_file('../data/final_data/davidson_income.geojson', driver = 'GeoJSON')
