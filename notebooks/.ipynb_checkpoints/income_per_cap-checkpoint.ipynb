# %%
import pandas as pd

# %%
# Just the 20 rows of meta data that pertain to per capita income + just the csv that pertains to per capita income
meta_per_cap = pd.read_csv('..\data\data-june12.csv')
data_per_cap = pd.read_csv('..\data\safegraph_open_census_data\data\cbg_b19.csv')

# %%
meta_per_cap['table_id']
# Out:
# 0     B19301Ae1
# 1     B19301Am1
# 2     B19301Be1
# 3     B19301Bm1
# 4     B19301Ce1
# 5     B19301Cm1
# 6     B19301De1
# 7     B19301Dm1
# 8     B19301e1
# 9     B19301Ee1
# 10    B19301Em1
# 11    B19301Fe1
# 12    B19301Fm1
# 13    B19301Ge1
# 14    B19301Gm1
# 15    B19301He1
# 16    B19301Hm1
# 17    B19301Ie1
# 18    B19301Im1
# 19    B19301m1
# Name: table_id, dtype: object

# %%
cleaned_col_names = [col_name.strip() for col_name in meta_per_cap['table_id']]

# %%
demographics2 = data_per_cap[cleaned_col_names]
demographics2.head()
# Out:
#    B19301Ae1  B19301Am1  B19301Be1  B19301Bm1  B19301Ce1  B19301Cm1  \
# 0    22722.0     5260.0    11745.0     3056.0        NaN        NaN
# 1    34688.0     8733.0    35294.0    24027.0        NaN        NaN
# 2    16314.0     8950.0    17497.0     3673.0        NaN        NaN
# 3    28199.0     5236.0    15540.0     2533.0        NaN        NaN
# 4    24128.0     4265.0    25823.0     8857.0        NaN        NaN
#
#    B19301De1  B19301Dm1  B19301e1  B19301Ee1  B19301Em1  B19301Fe1  B19301Fm1  \
# 0        NaN        NaN   20365.0        NaN        NaN        NaN        NaN
# 1        NaN        NaN   33336.0        NaN        NaN        NaN        NaN
# 2        NaN        NaN   17047.0        NaN        NaN        NaN        NaN
# 3        NaN        NaN   21400.0        NaN        NaN        NaN        NaN
# 4        NaN        NaN   23106.0        NaN        NaN    15971.0     3347.0
#
#    B19301Ge1  B19301Gm1  B19301He1  B19301Hm1  B19301Ie1  B19301Im1  B19301m1
# ...

# %%
column_headers = []

for index, rows in meta_per_cap.iterrows():
    
    column_headers_list = (rows.field_full_name)
    
    column_headers.append(column_headers_list)
    
print(column_headers)
# Out:
# ['PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE): Total: People who are White alone -- (Estimate)                                                                                                                                                                                                                                                                      ', 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE): Total: People who are White alone -- (Margin of Error)                                                                                                                                                                                                                                                               ', 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE): Total: People who are Black or African American alone -- (Estimate)       
# ...

# %%
demographics2.columns = [column_headers]
demographics2.head()
# Out:
#   PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE): Total: People who are White alone -- (Estimate)                                                                                                                                                                                                                                                                        \
# 0                                            22722.0
# 1                                            34688.0
# 2                                            16314.0
# 3                                            28199.0
# 4                                            24128.0
#
# ...

# %%
demographics2.shape
# Out:
# (220333, 20)

# %%
demog2 = demographics2[demographics2.columns.drop(list(demographics2.filter(regex='Margin of Error')))]
demog2.shape
# Out:
# (220333, 10)

# %%
demog2.head(10)
# Out:
#   PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE): Total: People who are White alone -- (Estimate)                                                                                                                                                                                                                                                                        \
# 0                                            22722.0
# 1                                            34688.0
# 2                                            16314.0
# 3                                            28199.0
# 4                                            24128.0
# 5                                            18908.0
# 6                                            35669.0
# 7                                            25458.0
# 8                                            23579.0
# 9                                            25288.0
#
# ...
