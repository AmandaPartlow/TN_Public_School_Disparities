# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
high_zones = gpd.read_file('../data/mnps/MNPS_HSZone_2021.shp')

# %%
high_zones.head()
# Out:
#       Shape_Leng    Shape_Area  CODE                SCHOOL_NAM   CLUS_NAME  \
# 0  229868.336792  1.167063e+09   110       Antioch High School     ANTIOCH
# 1  167154.722925  8.250695e+08   182    Cane Ridge High School  CANE RIDGE
# 2  153163.808014  5.913740e+08   615  John Overton High School     OVERTON
# 3  104374.857986  4.735933e+08   325     Glencliff High School   GLENCLIFF
# 4  177108.141081  1.259720e+09   435     Hillsboro High School   HILLSBORO
#
#                                             geometry
# 0  POLYGON ((1813162.200 657380.000, 1813035.400 ...
# 1  POLYGON ((1758041.000 619591.200, 1757728.800 ...
# 2  POLYGON ((1757728.800 619668.950, 1758041.000 ...
# 3  POLYGON ((1754450.700 656866.508, 1754457.615 ...
# 4  POLYGON ((1734657.535 665641.719, 1734740.356 ...

# %%
high_zones.crs = 'EPSG:4326'
high_zones = middle_zones.to_crs('EPSG:4326')

# %%
f, ax = plt.subplots(1, figsize=(15, 15))
high_zones.plot(column = 'SCHOOL_NAM', edgecolor = 'black', ax = ax)
plt.show()

# %%
high_zones.shape
# Out:
# (12, 6)

# %%
high_zones['SCHOOL_NAM'].value_counts()
# Out:
# Hunters Lane High School                             1
# Pearl-Cohn High School                               1
# Maplewood High School                                1
# McGavock High School                                 1
# Cane Ridge High School                               1
# John Overton High School                             1
# Whites Creek High School                             1
# Antioch High School                                  1
# Hillsboro High School                                1
# Stratford STEM Magnet School - Upper/Lower Campus    1
# Glencliff High School                                1
# Hillwood High School                                 1
# Name: SCHOOL_NAM, dtype: int64
